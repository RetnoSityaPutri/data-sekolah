# %% [markdown]
# <a href="https://colab.research.google.com/github/RetnoSityaPutri/data-sekolah/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# URL API untuk mengambil data sekolah
url = "https://api-sekolah-indonesia.vercel.app/sekolah?page=1&perPage=1000"

# Permintaan GET untuk mengambil data dari API
response = requests.get(url)

# Mengecek apakah permintaan berhasil
if response.status_code == 200:
    # Parsing data JSON dari respons
    data = response.json()

    # Menyimpan data dalam format JSON
    with open('data_sekolah.json', 'w') as json_file:
        json.dump(data, json_file, indent=4, ensure_ascii=False)

    print("Data berhasil diambil dan disimpan dalam file data_sekolah.json.")
else:
    print(f"Gagal mengambil data. Status code: {response.status_code}")
# Out:
# Data berhasil diambil dan disimpan dalam file data_sekolah.json.

# %%
import json

# Membaca file JSON
with open('/content/data_sekolah.json') as file:
    data = json.load(file)

# %%
# Mengakses data utama yang relevan
data_sekolah = data['dataSekolah']  # ganti 'data' sesuai dengan kunci yang benar

# Konversi ke DataFrame
df = pd.DataFrame(data_sekolah)

# Menampilkan DataFrame
display(df)
# Out:
#     kode_prop              propinsi kode_kab_kota         kabupaten_kota  \
# 0    010000    Prov. D.K.I. Jakarta      010100    Kab. Kepulauan Seribu
# 1    010000    Prov. D.K.I. Jakarta      010100    Kab. Kepulauan Seribu
# 2    010000    Prov. D.K.I. Jakarta      016000       Kota Jakarta Pusat
# 3    010000    Prov. D.K.I. Jakarta      016000       Kota Jakarta Pusat
# 4    010000    Prov. D.K.I. Jakarta      016000       Kota Jakarta Pusat
# ..        ...                   ...           ...                    ...
# 995  010000    Prov. D.K.I. Jakarta      016100       Kota Jakarta Utara
# 996  010000    Prov. D.K.I. Jakarta      016100       Kota Jakarta Utara
# 997  010000    Prov. D.K.I. Jakarta      016100       Kota Jakarta Utara
# 998  010000    Prov. D.K.I. Jakarta      016100       Kota Jakarta Utara
# 999  010000    Prov. D.K.I. Jakarta      016100       Kota Jakarta Utara
#
#      kode_kec                      kecamatan  \
# 0    010102      Kec. Kepulauan Seribu Utara
# 1    010101    Kec. Kepulauan Seribu Selatan
# 2    016002                     Kec. Menteng
# 3    016001                 Kec. Tanah Abang
# 4    016006                   Kec. Kemayoran
# ..        ...                            ...
# 995  016103               Kec. Tanjung Priok
# 996  016103               Kec. Tanjung Priok
# 997  016101                 Kec. Penjaringan
# 998  016104                        Kec. Koja
# 999  016103               Kec. Tanjung Priok
#
#                                        id      npsn  \
# 0    A0389C94-2BF5-E011-AC5A-69531DA3B5CC  20104465
# 1    80C29B94-2BF5-E011-AABF-732419A142F3  20104474
# 2    AA4D27B7-0ECB-4DC1-B1F5-3DAA8050DF5E  20107250
# 3    502E9E94-2BF5-E011-A7F4-BB042C90A8E0  20100504
# 4    20DA331D-25E1-44D5-BAAE-30D84421768C  20100303
# ..                                    ...       ...
# 995  60B68F95-2BF5-E011-BAF3-696BD752CEF1  20105114
# 996  D053B194-2BF5-E011-8304-C3FC3A585C68  20104939
# 997  C2B9AB69-6BC8-487C-A4D9-2E9EAA7BD36C  20107398
# 998  D070B394-2BF5-E011-AD25-197928D08DE1  20100690
# 999  30220F96-2BF5-E011-8F94-15A45018419C  20106619
#
#                                         sekolah bentuk status  \
# 0                     SDN PULAU HARAPAN 02 PAGI     SD      N
# 1                  SD NEGERI PULAU TIDUNG 02 PG     SD      N
# 2                             SMAS PSKD MANDIRI    SMA      S
# 3                        SDN Petamburan 06 Pagi     SD      N
# 4                         SMKS STRADA 1 JAKARTA    SMK      S
# ..                                          ...    ...    ...
# 995                            SD TAMAN HARAPAN     SD      S
# 996                      SDN Sunter Jaya 04 Pt.     SD      N
# 997                  SMAS WIJAYA KUSUMA JAKARTA    SMA      S
# 998  SD NEGERI RAWA BADAK SELATAN 09 PG JAKARTA     SD      N
# 999                              SMP Nurul Iman    SMP      S
#
#                                   alamat_jalan     lintang        bujur
# 0                                 Pulau Sabira  -5.2057000  106.4605000
# 1                 Jl. Lapangan Hijau Rt. 05/03  -5.7965000  106.4956000
# 2                     JL. GGSY RATULANGI NO.14  -6.1886000  106.8319000
# 3                     JL. PETAMBURAN II NO. 34  -6.1933000  106.8082000
# 4                     JL. GUNUNG SAHARI NO. 88  -6.1691000  106.8400000
# ..                                         ...         ...          ...
# 995                    Jl. Warakas V Gg. 2/141  -6.1252000  106.8822000
# 996                       Jl. Sunter Jaya IV A  -6.1563000  106.8670000
# 997                 JL. BANDENGAN UTARA NO. 80  -6.1359000  106.8017000
# 998                      Jl. Mundari Rt. 02/01  -6.1323000  106.9026000
# 999  Jl. Lagoa Kanal Komp. TNI-AD Kebon Bawang  -6.1132000  106.8879000
#
# [1000 rows x 14 columns]
